# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data01 = np.genfromtxt("Data/centaurEnergy01.csv", delimiter=',')
data1 = np.genfromtxt("Data/centaurEnergy1.csv", delimiter=',')
data10 = np.genfromtxt("Data/centaurEnergy10.csv", delimiter=',')
data50 = np.genfromtxt("Data/centaurEnergy50.csv", delimiter=',')
data100 = np.genfromtxt("Data/centaurEnergy100.csv", delimiter=',')
data120 = np.genfromtxt("Data/centaurEnergy120.csv", delimiter=',')
data150 = np.genfromtxt("Data/centaurEnergy150.csv", delimiter=',')
data200 = np.genfromtxt("Data/centaurEnergy200.csv", delimiter=',')
data300 = np.genfromtxt("Data/centaurEnergy300.csv", delimiter=',')
data500 = np.genfromtxt("Data/test500.csv", delimiter=',')

# error01 = (data01[1:] - data01[:-1]) / np.abs(data01[0])
# error1 = (data1[1:] - data1[:-1]) / np.abs(data1[0])
# error10 = (data10[1:] - data10[:-1]) / np.abs(data10[0])
# error120 = (data120[1:] - data120[:-1]) / np.abs(data120[0])

# %%
abs_error01 = abs(data01[1:] - data01[0])
abs_error1 = abs(data1[1:] - data1[0])
abs_error10 = abs(data10[1:] - data10[0])
abs_error50 = abs(data50[1:] - data50[0])
abs_error100 = abs(data100[1:] - data100[0])
abs_error120 = abs(data120[1:] - data120[0])
abs_error150 = abs(data150[1:] - data150[0])
abs_error200 = abs(data200[1:] - data200[0])
abs_error300 = abs(data300[1:] - data300[0])
abs_error500 = abs(data500[1:] - data500[0])

# %%
abs_error01_norm = (data01[1:] - data01[0]) / abs(data01[0])
abs_error1_norm = (data1[1:] - data1[0]) / abs(data1[0])
abs_error10_norm = (data10[1:] - data10[0]) / abs(data10[0])
abs_error50_norm = (data50[1:] - data50[0]) / abs(data50[0])
abs_error100_norm = (data100[1:] - data100[0]) / abs(data100[0])
abs_error120_norm = (data120[1:] - data120[0]) / abs(data120[0])
abs_error150_norm = (data150[1:] - data150[0]) / abs(data150[0])
abs_error200_norm = (data200[1:] - data200[0]) / abs(data200[0])
abs_error300_norm = (data300[1:] - data300[0]) / abs(data300[0])
abs_error500_norm = (data500[1:] - data500[0]) / abs(data500[0])

# %%
dt01 = np.arange(1, 1e5, 0.1)
dt1 = np.arange(1, 1e5, 1)
dt10 = np.arange(1, 1e5, 10)
dt50 = np.arange(1, 1e5, 50)
dt100 = np.arange(1, 1e5, 100)
dt120 = np.arange(1, 1e5, 120)
dt150 = np.arange(1, 1e5, 150)
dt200 = np.arange(1, 1e5, 200)
dt300 = np.arange(1, 1e5, 300)
dt500 = np.arange(1, 1e5, 500)

# %%
plt.plot(dt01[1:40001], abs_error01[:40000], label='0.1', linestyle='-.')
plt.plot(dt1[1:4001], abs_error1[:4000], label='1', linestyle='--')
plt.plot(dt10[1:401], abs_error10[:400], label='10', linestyle=':')
# plt.plot(dt50[1:801], abs_error50[:800], label='50', linestyle='--')

# plt.plot(dt120[1:], error120, label='120')
plt.legend()

# %%
avg_error01 = np.mean(abs_error01)
avg_error1 = np.mean(abs_error1)
avg_error10 = np.mean(abs_error10)
avg_error50 = np.mean(abs_error50)
avg_error100 = np.mean(abs_error100)
avg_error120 = np.mean(abs_error120)
avg_error150 = np.mean(abs_error150)
avg_error200 = np.mean(abs_error200)
avg_error300 = np.mean(abs_error300)
avg_error500 = np.mean(abs_error500)

# %%
avg_error01_norm = np.mean(abs_error01_norm)
avg_error1_norm = np.mean(abs_error1_norm)
avg_error10_norm = np.mean(abs_error10_norm)
avg_error50_norm = np.mean(abs_error50_norm)
avg_error100_norm = np.mean(abs_error100_norm)
avg_error120_norm = np.mean(abs_error120_norm)
avg_error150_norm = np.mean(abs_error150_norm)
avg_error200_norm = np.mean(abs_error200_norm)
avg_error300_norm = np.mean(abs_error300_norm)
avg_error500_norm = np.mean(abs_error500_norm)

# %%
dt_list = [0.1, 1, 10, 50, 100, 120, 150, 200, 300, 500]
avg_error_list = [avg_error01, avg_error1, avg_error10, avg_error50, avg_error100, avg_error120, avg_error150, avg_error200, avg_error300, avg_error500]

# %%
avg_error_list_norm = [avg_error01_norm, avg_error1_norm, avg_error10_norm, avg_error50_norm, avg_error100_norm, avg_error120_norm, avg_error150_norm, avg_error200_norm, avg_error300_norm, avg_error500_norm]

# %%
plt.plot(dt_list, avg_error_list)
plt.xlabel('dt')
plt.ylabel('avg_error')
# Out:
# Text(0, 0.5, 'avg_error')

# %%
plt.plot(dt_list, avg_error_list_norm)
plt.xlabel('dt')
plt.ylabel('avg error (not abs), normalized')
# Out:
# Text(0, 0.5, 'avg error (not abs), normalized')

# %%
# cumulative_error01 = np.cumsum(abs_error01)
# cumulative_error1 = np.cumsum(abs_error1)
# cumulative_error10 = np.cumsum(abs_error10)
# cumulative_error50 = np.cumsum(abs_error50)
# cumulative_error100 = np.cumsum(abs_error100)
# cumulative_error120 = np.cumsum(abs_error120)
# cumulative_error150 = np.cumsum(abs_error150)
# cumulative_error200 = np.cumsum(abs_error200)
# cumulative_error300 = np.cumsum(abs_error300)
# cumulative_error500 = np.cumsum(abs_error500)

# %%
# plt.plot(dt01[1:], cumulative_error01, label='0.1', linestyle='-.')
# plt.plot(dt1[1:], cumulative_error1, label='1', linestyle='--')
# plt.plot(dt10[1:], cumulative_error10, label='10', linestyle=':')
# plt.plot(dt50[1:], cumulative_error50, label='50', linestyle='--')
# plt.plot(dt100[1:], cumulative_error100, label='100')
# plt.plot(dt120[1:], cumulative_error120, label='120')
# plt.plot(dt150[1:], cumulative_error150, label='150')
# plt.plot(dt200[1:], cumulative_error200, label='200')
# plt.plot(dt300[1:], cumulative_error300, label='300')
# plt.plot(dt500[1:], cumulative_error500, label='500')
# plt.legend()

# %%
plt.plot(np.arange(1, 1e5, 1), data1, label='1')
plt.plot(np.arange(1, 1e5, 10), data10, label='10')
plt.plot(np.arange(1, 1e5, 120), data120, label='120')
plt.plot(dt01, data01, color='black', label='0.1')
plt.legend()

# %%
plt.plot(dt01[1:], error01, label='0.1')
plt.plot(dt1[1:], error1, label='1')
plt.plot(dt10[1:], error10, label='10')
# plt.plot(dt120[1:], error120, label='120')
plt.legend()

# %%
plt.plot([0.1, 1, 10, 120], [np.sum(np.abs(error01)), np.sum(np.abs(error1)), np.sum(np.abs(error10)), np.sum(np.abs(error120))])
plt.xscale('log')

# %%
plt.plot(dt01, data01)

# %%
data = np.genfromtxt("Data/totalEnergy1.csv", delimiter=',')
data
# Out:
# array([-4.41126569e+39, -4.41111720e+39, -4.41096839e+39, ...,
#        -4.46393385e+39, -4.46405189e+39, -4.46416943e+39])

# %%
plt.plot(data[:100000], 'bo', markersize=1)
